# %%
import pandas as pd

df = pd.read_csv("msa_1123/metadata.tsv", sep="\t")
print(df.shape)
# Out:
# (207592, 27)

# %%
mi_seqs = df[df.strain.str.startswith("USA/NY-NYUMC")]
print(mi_seqs.shape)
mi_seqs.head()
# Out:
# (871, 27)
#                       strain virus  gisaid_epi_isl genbank_accession  \
# 172769    USA/NY-NYUMC1/2020  ncov  EPI_ISL_414639                 ?
# 172770   USA/NY-NYUMC10/2020  ncov  EPI_ISL_418195                 ?
# 172771  USA/NY-NYUMC100/2020  ncov  EPI_ISL_421712                 ?
# 172772  USA/NY-NYUMC101/2020  ncov  EPI_ISL_421713                 ?
# 172773  USA/NY-NYUMC102/2020  ncov  EPI_ISL_421714                 ?
#
#               date         region country  division       location  \
# 172769  2020-03-04  North America     USA  New York  Nassau County
# 172770  2020-03-17  North America     USA  New York      Manhattan
# 172771  2020-03-18  North America     USA  New York       Brooklyn
# 172772  2020-03-18  North America     USA  New York       Brooklyn
# 172773  2020-03-18  North America     USA  New York       Brooklyn
#
#        region_exposure  ... Nextstrain_clade pangolin_lineage GISAID_clade  \
# ...

# %%
import lzma
from Bio import SeqIO

input_file = "msa_1123/manhattan.fasta"

seqs = SeqIO.parse(open(input_file, "rt"), "fasta")
{len(s.seq) for s in seqs}
# Out:
# {31264}
